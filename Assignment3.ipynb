# %%
import nltk
import svgling

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Prathamesh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
sent ='''The state is divided into 6 divisions and 36 districts, with the state capital being Mumbai, the most populous urban area in India, and Nagpur serving as the winter capital.The Godavari and Krishna are the two major rivers in the state and forests cover 16.47 per cent of the state's geographical area. The state is home to six UNESCO World Heritage Sites: Ajanta Caves, Ellora Caves, Elephanta Caves, Chhatrapati Shivaji Maharaj Terminus (formerly Victoria Terminus), The Victorian Gothic and Art Deco Ensembles of Mumbai and The Western Ghats, a heritage site made up of 39 individual properties of which 4 are in Maharashtra'''

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk import RegexpParser

# %%
#Q1)
grammar="VP:{<DT><VBD>}"
chunk_parser =RegexpParser(grammar)
tags = pos_tag(word_tokenize(sent))
tree =chunk_parser.parse(tags)
tree
# Out:
# Tree('S', [('The', 'DT'), ('state', 'NN'), ('is', 'VBZ'), ('divided', 'VBN'), ('into', 'IN'), ('6', 'CD'), ('divisions', 'NNS'), ('and', 'CC'), ('36', 'CD'), ('districts', 'NNS'), (',', ','), ('with', 'IN'), ('the', 'DT'), ('state', 'NN'), ('capital', 'NN'), ('being', 'VBG'), ('Mumbai', 'NNP'), (',', ','), ('the', 'DT'), ('most', 'RBS'), ('populous', 'JJ'), ('urban', 'JJ'), ('area', 'NN'), ('in', 'IN'), ('India', 'NNP'), (',', ','), ('and', 'CC'), ('Nagpur', 'NNP'), ('serving', 'NN'), ('as', 'IN'), ('the', 'DT'), ('winter', 'NN'), ('capital.The', 'NN'), ('Godavari', 'NNP'), ('and', 'CC'), ('Krishna', 'NNP'), ('are', 'VBP'), ('the', 'DT'), ('two', 'CD'), ('major', 'JJ'), ('rivers', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('state', 'NN'), ('and', 'CC'), ('forests', 'NNS'), ('cover', 'VBP'), ('16.47', 'CD'), ('per', 'IN'), ('cent', 'NN'), ('of', 'IN'), ('the', 'DT'), ('state', 'NN'), ("'s", 'POS'), ('geographical', 'JJ'), ('area', 'NN'), ('.', '.'), ('The', 'DT'), ('state', 'NN'), ('is', '
# ...

# %%
#Q2)
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 279.3 kB/s eta 0:00:46
#      --------------------------------------- 0.0/12.8 MB 279.3 kB/s eta 0:00:46
#      --------------------------------------- 0.1/12.8 MB 504.4 kB/s eta 0:00:26
#       -------------------------------------- 0.2/12.8 MB 615.9 kB/s eta 0:00:21
#      - -------------------------------------- 0.4/12.8 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.6/12.8 MB 1.8 MB/s eta 0:00:07
#      -- ------------------------------------- 0.8/12.8 MB 2.1 MB/s eta 0:00:06
# ...

# %%
nlp=spacy.load('en_core_web_sm')

# %%
sent1=nlp('''The state is divided into 6 divisions and 36 districts, with the state capital being Mumbai, the most populous urban area in India, and Nagpur serving as the winter capital.The Godavari and Krishna are the two major rivers in the state and forests cover 16.47 per cent of the state's geographical area. The state is home to six UNESCO World Heritage Sites: Ajanta Caves, Ellora Caves, Elephanta Caves, Chhatrapati Shivaji Maharaj Terminus (formerly Victoria Terminus), The Victorian Gothic and Art Deco Ensembles of Mumbai and The Western Ghats, a heritage site made up of 39 individual properties of which 4 are in Maharashtra''')

# %%
for ent in sent1.ents:
    if ent.label_ =='PERSON':
        print(ent.text)
# Out:
# Godavari
# Ajanta Caves
# Ellora Caves
# Elephanta Caves
# Chhatrapati Shivaji Maharaj Terminus
# Victoria Terminus
# Art Deco Ensembles

# %%
from spacy import displacy

# %%
displacy.render(sent1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The state is divided into
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  divisions and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  districts, with the state capital being
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
# ...
